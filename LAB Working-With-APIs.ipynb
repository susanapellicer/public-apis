# %%
import requests

# %%
tenders = requests.get("https://tenders.guru/api/es/tenders")
print("tenders:", tenders.status_code)
# Out:
# tenders: 200

# %%
print(tenders.text)
# Out:
# {"page_count":7146,"page_number":1,"page_size":100,"total":714598,"data":[{"id":"831333","date":"2021-06-29","deadline_date":"2021-06-07","deadline_length_days":"22","title":"Servicio de producci\u00f3n de c\u00e9lulas mesenquimales troncales adultas aut\u00f3logas y alog\u00e9nicas de medula \u00f3sea expandidas, vinculado al proyecto de investigaci\u00f3n PIC18\/00001","category":"services","sid":"7791427","src_url":"https:\/\/contrataciondelestado.es\/wps\/poc?uri=deeplink:detalle_licitacion&idEvl=IQ7l9PalhEWiEJrVRqloyA%3D%3D","purchaser":{"id":"1988","sid":null,"name":null},"type":{"id":"negotiated-without-publicity","name":"Negotiated without publicity","slug":"negotiated-without-publicity"},"awarded":[{"date":"2021-06-29","value_for_two":163560.4,"suppliers_id":"156913","suppliers":[{"name":"FUNDACI\u00d3N PARA LA INVESTIGACI\u00d3N BIOM\u00c9DICA DEL HOSPITAL GREGORIO MARA\u00d1\u00d3N","id":"156913","slug":"fundacion-para-la-investigacion-biomedica-del-hospital-gregorio-maran
# ...

# %%
import json

response = requests.get("https://tenders.guru/api/es/tenders")
response.content
results = response.json()
results
# Out:
# {'page_count': 7146,
#  'page_number': 1,
#  'page_size': 100,
#  'total': 714598,
#  'data': [{'id': '831333',
#    'date': '2021-06-29',
#    'deadline_date': '2021-06-07',
#    'deadline_length_days': '22',
#    'title': 'Servicio de producción de células mesenquimales troncales adultas autólogas y alogénicas de medula ósea expandidas, vinculado al proyecto de investigación PIC18/00001',
#    'category': 'services',
#    'sid': '7791427',
#    'src_url': 'https://contrataciondelestado.es/wps/poc?uri=deeplink:detalle_licitacion&idEvl=IQ7l9PalhEWiEJrVRqloyA%3D%3D',
#    'purchaser': {'id': '1988', 'sid': None, 'name': None},
#    'type': {'id': 'negotiated-without-publicity',
#     'name': 'Negotiated without publicity',
#     'slug': 'negotiated-without-publicity'},
#    'awarded': [{'date': '2021-06-29',
#      'value_for_two': 163560.4,
#      'suppliers_id': '156913',
#      'suppliers': [{'name': 'FUNDACIÓN PARA LA INVESTIGACIÓN BIOMÉDICA DEL HOSPITAL GREGORIO MARAÑÓN',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", None)

data = pd.DataFrame(results)
data.head(10)
# Out:
#    page_count  page_number  page_size   total  \
# 0        7146            1        100  714598
# 1        7146            1        100  714598
# 2        7146            1        100  714598
# 3        7146            1        100  714598
# 4        7146            1        100  714598
# 5        7146            1        100  714598
# 6        7146            1        100  714598
# 7        7146            1        100  714598
# 8        7146            1        100  714598
# 9        7146            1        100  714598
#
#                                                 data
# 0  {'id': '831333', 'date': '2021-06-29', 'deadli...
# 1  {'id': '831322', 'date': '2021-05-17', 'deadli...
# 2  {'id': '831319', 'date': '2021-06-29', 'title'...
# 3  {'id': '831318', 'date': '2021-06-29', 'title'...
# 4  {'id': '831317', 'date': '2021-05-26', 'deadli...
# 5  {'id': '831316', 'date': '2021-06-29', 'title'...
# 6  {'id': '831315', 'date': '2021-06-29', 'title'...
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['data'])
pd.DataFrame(dict(data['data']))
data_data = pd.DataFrame(dict(data['data'])).transpose()
data_data
# Out:
#         id        date deadline_date deadline_length_days  \
# 0   831333  2021-06-29    2021-06-07                   22
# 1   831322  2021-05-17    2021-06-01                   15
# 2   831319  2021-06-29           NaN                  NaN
# 3   831318  2021-06-29           NaN                  NaN
# 4   831317  2021-05-26    2021-06-11                   16
# 5   831316  2021-06-29           NaN                  NaN
# 6   831315  2021-06-29           NaN                  NaN
# 7   831314  2021-06-29           NaN                  NaN
# 8   831313  2021-06-29           NaN                  NaN
# 9   831312  2021-06-29           NaN                  NaN
# 10  831311  2021-06-29           NaN                  NaN
# 11  831310  2021-06-29           NaN                  NaN
# 12  831309  2021-06-29           NaN                  NaN
# 13  831308  2021-06-29           NaN                  NaN
# 14  831297  2021-05-04    2021-05-19                   15
# ...

# %%
flatten (data_data,['purchaser','type'])
# Out:
#         id        date deadline_date deadline_length_days  \
# 0   831333  2021-06-29    2021-06-07                   22
# 1   831322  2021-05-17    2021-06-01                   15
# 2   831319  2021-06-29           NaN                  NaN
# 3   831318  2021-06-29           NaN                  NaN
# 4   831317  2021-05-26    2021-06-11                   16
# 5   831316  2021-06-29           NaN                  NaN
# 6   831315  2021-06-29           NaN                  NaN
# 7   831314  2021-06-29           NaN                  NaN
# 8   831313  2021-06-29           NaN                  NaN
# 9   831312  2021-06-29           NaN                  NaN
# 10  831311  2021-06-29           NaN                  NaN
# 11  831310  2021-06-29           NaN                  NaN
# 12  831309  2021-06-29           NaN                  NaN
# 13  831308  2021-06-29           NaN                  NaN
# 14  831297  2021-05-04    2021-05-19                   15
# ...

# %%
#API2

# %%
import requests
response= requests.get('https://openlibrary.org/search.json?q=the+lord+of+the+rings')

book = pd.DataFrame(response.json())
book.head()
# Out:
#    numFound  start  numFoundExact  \
# 0       786      0           True
# 1       786      0           True
# 2       786      0           True
# 3       786      0           True
# 4       786      0           True
#
#                                                 docs  num_found  \
# 0  {'key': '/works/OL27448W', 'type': 'work', 'se...        786
# 1  {'key': '/works/OL14933414W', 'type': 'work', ...        786
# 2  {'key': '/works/OL27658078W', 'type': 'work', ...        786
# 3  {'key': '/works/OL27479W', 'type': 'work', 'se...        786
# 4  {'key': '/works/OL27516W', 'type': 'work', 'se...        786
#
#                        q offset
# 0  the lord of the rings   None
# 1  the lord of the rings   None
# 2  the lord of the rings   None
# 3  the lord of the rings   None
# 4  the lord of the rings   None

# %%
def flatten1(book, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(book[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        book = pd.concat([book, flattened], axis=1)
        book = data.drop(column, axis=1)
    return book

# %%
dict(book['docs'])
pd.DataFrame(dict(book['docs']))
pd.DataFrame(dict(book['docs'])).transpose()
# Out:
#                    key  type  \
# 0      /works/OL27448W  work
# 1   /works/OL14933414W  work
# 2   /works/OL27658078W  work
# 3      /works/OL27479W  work
# 4      /works/OL27516W  work
# 5   /works/OL26424627W  work
# 6    /works/OL2089932W  work
# 7   /works/OL12413029W  work
# 8   /works/OL34315353W  work
# 9    /works/OL8527426W  work
# 10  /works/OL27192798W  work
# 11  /works/OL18146933W  work
# 12  /works/OL33733658W  work
# 13  /works/OL28758970W  work
# 14  /works/OL33918153W  work
# 15  /works/OL24532603W  work
# 16  /works/OL28830902W  work
# 17  /works/OL27739988W  work
# 18  /works/OL30214942W  work
# 19  /works/OL26009314W  work
# 20   /works/OL3469307W  work
# 21  /works/OL31711215W  work
# 22  /works/OL20652017W  work
# 23  /works/OL32342319W  work
# 24  /works/OL31972551W  work
# 25   /works/OL9262013W  work
# 26  /works/OL33984094W  work
# 27   /works/OL9356256W  work
# 28   /works/OL3062799W  work
# 29  /works/OL12693815W  work
# 30  /works/OL34507831W  work
# ...

# %%
nested_columns = ['docs']

flat = flatten(book,nested_columns)
flat
# Out:
#     numFound  start  numFoundExact  num_found                      q offset  \
# 0        786      0           True        786  the lord of the rings   None
# 1        786      0           True        786  the lord of the rings   None
# 2        786      0           True        786  the lord of the rings   None
# 3        786      0           True        786  the lord of the rings   None
# 4        786      0           True        786  the lord of the rings   None
# 5        786      0           True        786  the lord of the rings   None
# 6        786      0           True        786  the lord of the rings   None
# 7        786      0           True        786  the lord of the rings   None
# 8        786      0           True        786  the lord of the rings   None
# 9        786      0           True        786  the lord of the rings   None
# 10       786      0           True        786  the lord of the rings   None
# ...

# %%
#API3

# %%
import requests
response= requests.get('https://api.covid19tracker.ca/summary')

covid = pd.DataFrame(response.json())
covid.head()
# Out:
#                                                 data         last_updated
# 0  {'latest_date': '2023-06-12', 'change_cases': ...  2023-06-13 00:06:07

# %%
covid.shape
# Out:
# (1, 2)

# %%
def flatten1(covid, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(covid[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        covid = pd.concat([covid, flattened], axis=1)
        covid = data.drop(column, axis=1)
    return covid

# %%
dict(covid['data'])
pd.DataFrame(dict(covid['data']))
pd.DataFrame(dict(covid['data'])).transpose()
# Out:
#   change_boosters_1 change_boosters_2 change_cases change_criticals  \
# 0               100              5093            1                0
#
#   change_fatalities change_hospitalizations change_recoveries change_tests  \
# 0                 0                       0                 0            0
#
#   change_vaccinated change_vaccinations  ... total_boosters_2 total_cases  \
# 0                67                5313  ...         11959848     4567667
#
#   total_criticals total_fatalities total_hospitalizations total_recoveries  \
# 0             149            50470                   2718          3954939
#
#   total_tests total_vaccinated total_vaccinations total_vaccines_distributed
# 0    62537526         31627383           98152812                  101586018
#
# [1 rows x 23 columns]

# %%
nested_columns = ['data']

flat = flatten(covid,nested_columns)
flat
# Out:
#           last_updated data_change_boosters_1 data_change_boosters_2  \
# 0  2023-06-13 00:06:07                    100                   5093
#
#   data_change_cases data_change_criticals data_change_fatalities  \
# 0                 1                     0                      0
#
#   data_change_hospitalizations data_change_recoveries data_change_tests  \
# 0                            0                      0                 0
#
#   data_change_vaccinated  ... data_total_boosters_2 data_total_cases  \
# 0                     67  ...              11959848          4567667
#
#   data_total_criticals data_total_fatalities data_total_hospitalizations  \
# 0                  149                 50470                        2718
#
#   data_total_recoveries data_total_tests data_total_vaccinated  \
# 0               3954939         62537526              31627383
#
#   data_total_vaccinations data_total_vaccines_distributed
# 0                98152812                       101586018
#
# ...
